# %% [markdown]
# ### simple line plot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig=plt.figure()
ax=plt.axes()

# %%
fig=plt.figure()
ax=plt.axes()
x=np.linspace(0,10,1000)
ax.plot(x,np.sin(x));

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x-0),color='blue')
plt.plot(x,np.sin(x-1),color='g')
plt.plot(x,np.sin(x-2),color='0.75')
plt.plot(x,np.sin(x-3),color='#FFDD44')
plt.plot(x,np.sin(x-4),color='chartreuse')

# %%
plt.plot(x,x+1,linestyle='solid')
plt.plot(x,x+2,linestyle='dashed')
plt.plot(x,x+4,linestyle='--')
plt.plot(x,x+5,linestyle=':');

# %% [markdown]
# ### adjusting plots

# %%
plt.plot(x,np.sin(x))
plt.xlim(-1,11)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x,np.sin(x))
plt.axis('tight')
# Out:
# (-0.5, 10.5, -1.0999971452300779, 1.099999549246729)

# %%
plt.plot(x,np.sin(x))
plt.axis('equal')
# Out:
# (-0.5, 10.5, -1.0999971452300779, 1.099999549246729)

# %% [markdown]
# ### labeling plots

# %%
plt.plot(x,np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sinx")
# Out:
# Text(0, 0.5, 'sinx')

# %% [markdown]
# ### scatter plot

# %%
x=np.linspace(0,10,30)
y=np.sin(x)
plt.plot(x,y,'o',color='black')

# %%
plt.plot(x,y,'-ok')

# %%
plt.scatter(x,y,marker='o')

# %% [markdown]
# ### basic error

# %%
x=np.linspace(0,10,50)
dy=0.8
y=np.sin(x)+dy*np.random.randn(50)
plt.errorbar(x,y,yerr=dy,fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### density and contour

# %%
def f(x,y):return np.sin(x)**10+np.cos(10+y*x)*np.cos(x)
x=np.linspace(0,5,50)
y=np.linspace(0,5,40)
x,y=np.meshgrid(x,y)
z=f(x,y)

# %%
plt.contour(x,y,z,colors='black')

# %% [markdown]
# ### histograms,binnings and density

# %%
data=np.random.randn(1000)

# %%
plt.hist(data)
# Out:
# (array([  4.,   9.,  38.,  90., 200., 263., 206., 122.,  49.,  19.]),
#  array([-3.57848711, -2.94639594, -2.31430478, -1.68221362, -1.05012246,
#         -0.4180313 ,  0.21405986,  0.84615102,  1.47824218,  2.11033334,
#          2.74242451]),
#  <a list of 10 Patch objects>)

# %%
mean=[0,0]
cov=[[1,1],[1,2]]
x,y=np.random.multivariate_normal(mean,cov,10000).T

# %%
plt.hist2d(x,y,bins=30,cmap='Blues')
cb=plt.colorbar()
cb.set_label('counts in bin')

# %% [markdown]
# ### grids

# %%
ax=plt.axes(xscale='log',yscale='log')
ax.grid()

# %%
fig=plt.figure()
ax=plt.axes(projection='3d')
